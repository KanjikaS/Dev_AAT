# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (2.1.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.shape
# Out:
# (1460, 81)

# %%
df = pd.concat([test, train])

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            HLS    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         6   2010        WD         Normal        NaN
# 1         6   2010        WD         Normal        NaN
# 2         3   2010        WD         Normal        NaN
# 3         6   2010        WD         Normal        NaN
# 4         1   2010        WD         Normal        NaN
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal   175000.0
# 1456      2   2010        WD         Normal   210000.0
# 1457      5   2010        WD         Normal   266500.0
# 1458      4   2010        WD         Normal   142125.0
# 1459      6   2008        WD         Normal   147500.0
#
# [2919 rows x 81 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_vars = list(df.select_dtypes(include=numerics).columns)
data = df[numerical_vars]

# %%
data.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 0       1961          1961         0.0       468.0  ...         140
# 1       1958          1958       108.0       923.0  ...         393
# 2       1997          1998         0.0       791.0  ...         212
# 3       1998          1998        20.0       602.0  ...         360
# 4       1992          1992         0.0       263.0  ...           0
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 0            0              0          0          120         0        0
# 1           36              0          0            0         0    12500
# 2           34              0          0            0         0        0
# 3           36              0          0            0         0        0
# 4           82              0          0          144         0        0
#
#    MoSold  YrSold  SalePrice
# 0       6    2010        NaN
# 1       6    2010        NaN
# 2       3    2010        NaN
# 3       6    2010        NaN
# 4       1    2010        NaN
#
# [5 rows x 38 columns]

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000  ...
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235  ...
# std       1.113131    30.291442     20.894344   179.334253   455.610826  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1953.500000   1965.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1993.000000     0.000000   368.500000  ...
# 75%       6.000000  2001.000000   2004.000000   164.000000   733.000000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean     93.709832    47.486811      23.098321     2.602261    16.062350
# std     126.526589    67.575493      64.244246    25.188169    56.184365
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    26.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2919.000000   2919.000000  2919.000000  2919.000000    1460.000000
# mean      2.251799     50.825968     6.213087  2007.792737  180921.195890
# std      35.663946    567.402211     2.714762     1.314964   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
mean = data['SalePrice'].mean()
standard_deviation = data['SalePrice'].std()

# %%
standard_deviation
# Out:
# 79442.50288288662

# %%
# %pip install scipy
# Out:
# Collecting scipyNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\kanji\onedrive\desktop\dev\environ\lib\site-packages (from scipy) (1.26.2)
# Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl (44.1 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.11.4

# %%
# load scipy's statistics module
from scipy import stats
 
# Emperor penguins height statistics (in inches)
mean = mean
standard_deviation = standard_deviation
 
# Create normal distribution using the 'norm' class
# loc - specifies the mean
# scale - specifies the standard deviation
normal_curve= stats.norm(
    loc=mean, 
    scale=standard_deviation
)

# %%
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (3.8.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\kanji\onedrive\desktop\dev\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading seaborn-0.13.1-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.8 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/294.8 kB ? eta -:--:--
#    --------------- ------------------------ 112.6/294.8 kB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 235.5/294.8 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.8/294.8 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.1

# %%
sample = normal_curve.rvs(6000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
 
# Use seaborn style and increase font size 
sns.set_theme(style='ticks', font_scale=1.5)
# set figure dimensions 
plt.figure(figsize=(12, 6))
plt.hist(sample, bins=100)
 
plt.title("SalesPrice for house", pad=20)
plt.xlabel("SalePrice", labelpad=10)
plt.ylabel("Frequency", labelpad=10)
plt.show()

# %% [markdown]
# ## Greedy Feature Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(labels=['SalePrice'], axis=1),
    data['SalePrice'],
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((2043, 37), (876, 37))

# %%
# find and remove correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_train, 0.8)
print('correlated features: ', len(set(corr_features)) )
# Out:
# correlated features:  4

# %%
# removed correlated  features
X_train.drop(labels=corr_features, axis=1, inplace=True)
X_test.drop(labels=corr_features, axis=1, inplace=True)

X_train.shape, X_test.shape
# Out:
# ((2043, 33), (876, 33))

# %%
X_train.fillna(0, inplace=True)

# %%
y_train.fillna(0,inplace = True)

# %%
import numpy as np

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

sfs1 = SFS(RandomForestRegressor(), 
           k_features=10, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='r2',
           cv=3)

sfs1 = sfs1.fit(np.array(X_train), y_train)
# Out:
# [2024-01-24 11:00:11] Features: 1/10 -- score: 0.5792492866196611
# [2024-01-24 11:01:11] Features: 2/10 -- score: 0.8767896797123346
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
